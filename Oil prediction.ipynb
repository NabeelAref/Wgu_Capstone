# %% [markdown]
# # Oil Prediction Prices
#
# ![AdobeStock_304751663-4.jpeg](attachment:AdobeStock_304751663-4.jpeg)

# %%
# %matplotlib inline
import Data
import Charts
import Prediction
import GUI
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data_object = Data.Data()

# %%
data_object.get_all_values()
# Out:
#            Date  Price   Open   High    Low    Vol.  Change %
# 0    2010-01-04  81.51  79.63  81.79  79.63  263540      2.71
# 1    2010-01-05  81.77  81.63  82.00  80.95  258890      0.32
# 2    2010-01-06  83.18  81.43  83.52  80.85  370060      1.72
# 3    2010-01-07  82.66  83.20  83.36  82.26  246630     -0.63
# 4    2010-01-08  82.75  82.65  83.47  81.80  310380      0.11
# ...         ...    ...    ...    ...    ...     ...       ...
# 3467 2023-04-25  77.07  78.74  79.07  76.50  361650     -2.15
# 3468 2023-04-26  74.30  77.08  77.93  74.05  497780     -3.59
# 3469 2023-04-27  74.76  74.38  75.28  74.03  345880      0.62
# 3470 2023-04-28  76.78  74.91  76.92  73.93  328400      2.70
# 3471 2023-05-01  75.66  76.66  76.69  74.53  215020     -1.46
#
# [3472 rows x 7 columns]

# %%
chart = Charts.Charts()
chart.draw_chart1(data_object)
# Out:
# <div>                            <div id="c8a7ced7-a4e5-42b9-8e5e-5e9fb9b7c7df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8a7ced7-a4e5-42b9-8e5e-5e9fb9b7c7df")) {                    Plotly.newPlot(                        "c8a7ced7-a4e5-42b9-8e5e-5e9fb9b7c7df",                        [{"y":[81.51,81.77,83.18,82.66,82.75,82.52,80.79,79.65,79.39,78.0,79.02,77.62,76.08,74.54,75.26,74.71,73.67,73.64,72.89,74.43,77.23,76.98,73.14,71.19,71.89,73.75,74.52,75.28,74.13,77.01,77.33,79.06,79.81,80.16,78.86,80.0,78.17,79.66,78.7,79.68,80.87,80.21,81.5,81.87,81.49,82.09,82.11,81.24,79.8,81.7,82.93,82.2,80.68,81.25,81.91,80.61,80.53,80.0,82.17,82.37,83.76,84.87,86.62,86.84,85.88,85.39,84.92,84.34,84.05,85.84,85.51,83.24,81.45,83.45,83.68,83.7,85.12,84.2,82.
# ...

# %%
linearReg =Prediction.Prediction(data_object)
traces = linearReg.linearReg()
chart.draw_chart2(traces[0],traces[1])
# Out:
# R2 Train: 0.08314370423806916
# R2 Test: -0.03289551817655023
# Mean Squared Train : 136.70566918698128
# Mean Squared Test : 105.03513036874766
# ...

# %%
print("Graph 1")
chart.draw_chart3(data_object)
# Out:
# Graph 1

# %%
print("Graph 2")
chart.draw_chart4(data_object)
# Out:
# Graph 2

# %%
print("Graph 3")
chart.draw_chart5(data_object)
# Out:
# Graph 3

# %% [markdown]
# # Run cells again if data was sliced to keep data accurate

# %%
gui=GUI.GUI(data_object)
# Out:
# IntSlider(value=0, description='Start:', max=3472)
# Output()
# IntSlider(value=0, description='End:', max=3472)
# Label(value='')
# Output()
# Button(description='Cut and Predict', style=ButtonStyle())
# Output()

# %%
# %%js
# //this code and the code below it takes care of the themeing of the page.
# document.getElementById("notebook-container").style="background-color:#333333;color:#ffffff;"
# document.getElementById("notebook").style="background-color:#000000;"

# %%
# %%html
# <style>
# h1,th,td,.widget-label, .widget-readout, .jupyter-widget-readout, .jupyter-widget-label,.widget-inline-hbox .widget-label, .jupyter-widget-inline-hbox .jupyter-widget-label
# {
#     color:#ffffff;
# }
# div.output_area pre, bod,.navbar-default,.navbar-nav,dropdown-toggle
# {color:#ffffff;}
#  .rendered_html tbody tr:nth-child(odd){
#      background:#555555;
#  }
# .navbar-default, .navbar-collapse, .navbar-default, .navbar-form, body > #header  {
#      background-color:#333333;
#      border-color:#000000;
#  }
# .navbar-default .navbar-nav > li > a, #kernel_indicator .kernel_indicator_name
# {
#     color:#ffffff;
# }
# .btn-default,.form-control
# {
#     background-color:#333333;
#     color:#ffffff;
#     border-color:#000000;
# }
# body
# {
#     color:#ffffff;
# }
# #login_widget > .button, #logout, #shutdown
# {
#     color:#ffffff;
#     background-color:#333333;
# }
# div.input
# {
#     display:none;
# }
# </style>
# Out:
# <style>
# h1,th,td,.widget-label, .widget-readout, .jupyter-widget-readout, .jupyter-widget-label,.widget-inline-hbox .widget-label, .jupyter-widget-inline-hbox .jupyter-widget-label
# {
#     color:#ffffff;
# }
# div.output_area pre, bod,.navbar-default,.navbar-nav,dropdown-toggle
# {color:#ffffff;}
#  .rendered_html tbody tr:nth-child(odd){
#      background:#555555;
#  }
# .navbar-default, .navbar-collapse, .navbar-default, .navbar-form, body > #header  {
#      background-color:#333333;
#      border-color:#000000;
#  }
# .navbar-default .navbar-nav > li > a, #kernel_indicator .kernel_indicator_name
# {
#     color:#ffffff;
# }
# .btn-default,.form-control
# {
#     background-color:#333333;
#     color:#ffffff;
#     border-color:#000000;
# }
# body
# {
#     color:#ffffff;
# }
# #login_widget > .button, #logout, #shutdown
# {
#     color:#ffffff;
#     background-color:#333333;
# }
# div.input
# {
#     display:none;
# }
# </style>
